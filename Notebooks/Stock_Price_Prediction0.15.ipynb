# %%
# Import
# %matplotlib inline
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt



from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import os
from sklearn import metrics
from scipy.stats import zscore
from keras.models import Sequential, Model
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import Input
# Out:
# Using TensorFlow backend.

# %%
# Import data
data = pd.read_csv('prices.csv', parse_dates=['Date'], 
                   low_memory=False)

# %%
data.shape
# Out:
# (1744, 19)

# %%
data = data[::-1]

# %%
data.head()
# Out:
#            Date  BOLSAA_Price  Bovespa_Brazil_50_Price  CAD_USD_Price  \
# 1743 2011-08-15         20.60                  7739.02         1.0200
# 1742 2011-08-16         20.78                  7703.14         1.0180
# 1741 2011-08-17         20.86                  7808.20         1.0200
# 1740 2011-08-18         20.11                  7538.04         1.0099
# 1739 2011-08-19         19.60                  7414.85         1.0101
#
#       Canada_10Y_BY_Price  Canada_30Y_BY_Price  EUR_USD_Price  \
# 1743                2.502                3.138         1.4446
# 1742                2.452                3.113         1.4409
# 1741                2.396                3.052         1.4425
# 1740                2.300                2.958         1.4331
# 1739                2.301                2.958         1.4398
#
#       Euro_Stoxx_50_Price  JPY_USD_Price  Nikkei_225_Price  \
# 1743              2324.48         0.0130           9086.41
# 1742              2323.67         0.0130           9107.43
# 1741              2331.12         0.0130           9057.26
# 1740              2206.61         0.0130           8943.76
# 1739              2159.07         0.0131           8719.24
#
#       Shanghai_Shenzhen_CSI_300_Price  SnP_TSX_Composite_Price  SnP_500_Price  \
# 1743                          2917.88                 12683.61        1204.49
# 1742                          2897.58                 12530.71        1192.76
# 1741                          2886.01                 12579.61        1193.89
# 1740                          2834.25                 12186.71        1140.65
# 1739                          2807.66                 12007.47        1123.53
#
#       US_10Y_BY_Price  US_30Y_BY.csv_Price  Holiday  weekend month quarter
# 1743            2.308                3.773    False    False   Aug      Q3
# 1742            2.225                3.672    False    False   Aug      Q3
# 1741            2.167                3.565    False    False   Aug      Q3
# 1740            2.068                3.424    False    False   Aug      Q3
# 1739            2.067                3.397    False    False   Aug      Q3

# %%
data.dtypes
# Out:
# Date                               datetime64[ns]
# BOLSAA_Price                              float64
# Bovespa_Brazil_50_Price                   float64
# CAD_USD_Price                             float64
# Canada_10Y_BY_Price                       float64
# Canada_30Y_BY_Price                       float64
# EUR_USD_Price                             float64
# Euro_Stoxx_50_Price                       float64
# JPY_USD_Price                             float64
# Nikkei_225_Price                          float64
# Shanghai_Shenzhen_CSI_300_Price           float64
# SnP_TSX_Composite_Price                   float64
# SnP_500_Price                             float64
# US_10Y_BY_Price                           float64
# US_30Y_BY.csv_Price                       float64
# Holiday                                      bool
# weekend                                      bool
# month                                      object
# quarter                                    object
# dtype: object

# %%
sum(data.isnull().sum() >0)
# Out:
# 0

# %%
# Drop date variable
data.drop(['Date'], axis=1, inplace=True)

# %%
data['month'] = data.month.astype('category')

# %%
data.month = data.month.cat.set_categories(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %%
data.month.cat.categories
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object')

# %%
data.month = data.month.cat.codes + 1

# %%
data['quarter'] = data.quarter.astype('category')

# %%
data.quarter = data.quarter.cat.set_categories(['Q1', 'Q2', 'Q3', 'Q4'])

# %%
data.quarter.cat.categories
# Out:
# Index(['Q1', 'Q2', 'Q3', 'Q4'], dtype='object')

# %%
data.quarter = data.quarter.cat.codes+1

# %%
corr = data.corr()
corr.style.background_gradient()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:581: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)
# <style  type="text/css" >
#     #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col0 {
#             background-color:  #023858;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col1 {
#             background-color:  #1278b4;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col2 {
#             background-color:  #abbfdc;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col3 {
#             background-color:  #b1c2de;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col4 {
#             background-color:  #c4cbe3;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col5 {
#             background-color:  #abbfdc;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col6 {
#             background-color:  #2182b9;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col7 {
#             background-color:  #bdc8e1;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col8 {
#             background-color:  #1379b5;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col9 {
#             background-color:  #589ec8;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col10 {
#             background-color:  #2987bc;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col11 {
#             background-color:  #0a73b2;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col12 {
#             background-color:  #89b1d4;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col13 {
#             background-color:  #b9c6e0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col14 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col15 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col16 {
#             background-color:  #f9f2f8;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row0_col17 {
#             background-color:  #f7f0f7;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col0 {
#             background-color:  #157ab5;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col1 {
#             background-color:  #023858;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col2 {
#             background-color:  #cacee5;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col3 {
#             background-color:  #a2bcda;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col4 {
#             background-color:  #cdd0e5;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col5 {
#             background-color:  #bfc9e1;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col6 {
#             background-color:  #0570b0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col7 {
#             background-color:  #b3c3de;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col8 {
#             background-color:  #056aa6;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col9 {
#             background-color:  #0f76b3;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col10 {
#             background-color:  #04639b;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col11 {
#             background-color:  #045e93;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col12 {
#             background-color:  #5a9ec9;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col13 {
#             background-color:  #d3d4e7;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col14 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col15 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col16 {
#             background-color:  #fef6fa;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row1_col17 {
#             background-color:  #fdf5fa;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col0 {
#             background-color:  #f0eaf4;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col2 {
#             background-color:  #023858;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col3 {
#             background-color:  #187cb6;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col4 {
#             background-color:  #056ba7;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col5 {
#             background-color:  #034c78;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col6 {
#             background-color:  #f4eef6;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col7 {
#             background-color:  #045280;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col8 {
#             background-color:  #fbf3f9;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col9 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col10 {
#             background-color:  #fbf4f9;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col11 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col12 {
#             background-color:  #dddbec;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col13 {
#             background-color:  #3790c0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col14 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col15 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col16 {
#             background-color:  #e7e3f0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row2_col17 {
#             background-color:  #e7e3f0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col0 {
#             background-color:  #c0c9e2;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col1 {
#             background-color:  #abbfdc;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col2 {
#             background-color:  #056caa;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col3 {
#             background-color:  #023858;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col4 {
#             background-color:  #034267;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col5 {
#             background-color:  #04598c;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col6 {
#             background-color:  #9fbad9;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col7 {
#             background-color:  #358fc0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col8 {
#             background-color:  #a9bfdc;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col9 {
#             background-color:  #dddbec;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col10 {
#             background-color:  #abbfdc;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col11 {
#             background-color:  #b1c2de;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col12 {
#             background-color:  #0568a3;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col13 {
#             background-color:  #034f7d;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col14 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col15 {
#             background-color:  #fff7fb;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col16 {
#             background-color:  #ece7f2;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row3_col17 {
#             background-color:  #ece7f2;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row4_col0 {
#             background-color:  #e5e1ef;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row4_col1 {
#             background-color:  #e7e3f0;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row4_col2 {
#             background-color:  #04649e;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a620c1row4_col3 {
#             background-color:  #034369;
#         }    #T_51e67ae0_80f2_11e8_8164_029830a

# %%
train_index = round(len(data)*0.8)

# %%
# Scale data
def normalize(series):
    return (series - np.mean(series))/(max(series) - min(series))

# %%
data_norm = pd.concat([data.drop(['Holiday', 'weekend', 'month', 'quarter'], axis=1).apply(normalize), 
data.filter(items = ('Holiday', 'weekend', 'month', 'quarter'), axis=1)], axis=1)

# %%
data_norm.head()
# Out:
#       BOLSAA_Price  Bovespa_Brazil_50_Price  CAD_USD_Price  \
# 1743     -0.402050                -0.199446       0.443088
# 1742     -0.393055                -0.203757       0.437310
# 1741     -0.389057                -0.191136       0.443088
# 1740     -0.426538                -0.223590       0.413906
# 1739     -0.452025                -0.238390       0.414484
#
#       Canada_10Y_BY_Price  Canada_30Y_BY_Price  EUR_USD_Price  \
# 1743             0.338416             0.407178       0.535464
# 1742             0.311606             0.392777       0.526490
# 1741             0.281579             0.357639       0.530371
# 1740             0.230105             0.303491       0.507572
# 1739             0.230641             0.303491       0.523822
#
#       Euro_Stoxx_50_Price  JPY_USD_Price  Nikkei_225_Price  \
# 1743            -0.384621       0.592551         -0.416693
# 1742            -0.385063       0.592551         -0.415376
# 1741            -0.381000       0.592551         -0.418519
# 1740            -0.448899       0.592551         -0.425629
# 1739            -0.474823       0.611782         -0.439693
#
#       Shanghai_Shenzhen_CSI_300_Price  SnP_TSX_Composite_Price  SnP_500_Price  \
# 1743                        -0.039119                -0.233589      -0.410328
# 1742                        -0.045333                -0.262796      -0.416941
# 1741                        -0.048875                -0.253455      -0.416304
# 1740                        -0.064719                -0.328507      -0.446321
# 1739                        -0.072858                -0.362745      -0.455974
#
#       US_10Y_BY_Price  US_30Y_BY.csv_Price  Holiday  weekend  month  quarter
# 1743         0.066042             0.404758    False    False      8        3
# 1742         0.018802             0.350632    False    False      8        3
# 1741        -0.014209             0.293290    False    False      8        3
# 1740        -0.070555             0.217727    False    False      8        3
# 1739        -0.071124             0.203258    False    False      8        3

# %%
train_data = {}
test_data = {}
train_dep = {}
test_dep = {}

# %%
for col_names in data_norm.columns[:14]:
    print(col_names, "\n")
    train_data[col_names] = data_norm.iloc[:train_index,:].drop(col_names, axis=1)
    test_data[col_names] = data_norm.iloc[train_index:,:].drop(col_names, axis=1)

    train_dep[col_names] = data_norm.iloc[:train_index][col_names]
    test_dep[col_names] = data_norm.iloc[train_index:][col_names]
# Out:
# BOLSAA_Price
#
# Bovespa_Brazil_50_Price
#
# CAD_USD_Price
#
# Canada_10Y_BY_Price
#
# Canada_30Y_BY_Price
#
# EUR_USD_Price
#
# Euro_Stoxx_50_Price
#
# JPY_USD_Price
#
# Nikkei_225_Price
#
# Shanghai_Shenzhen_CSI_300_Price
#
# SnP_TSX_Composite_Price
#
# SnP_500_Price
#
# US_10Y_BY_Price
#
# US_30Y_BY.csv_Price

# %%
train_x = train_data['Canada_10Y_BY_Price']
test_x = test_data['Canada_10Y_BY_Price']
train_y = train_dep['Canada_10Y_BY_Price']
test_y = test_dep['Canada_10Y_BY_Price']

# %%
n_stocks = train_x.shape[1]

# %%
train_x.shape
# Out:
# (1395, 17)

# %%
model = Sequential()
model.add(Dense(100, input_dim=n_stocks, activation='linear'))
model.add(Dense(50, activation='linear'))
model.add(Dense(25, activation='linear'))
model.add(Dense(10, activation='linear'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam',
             metrics=['mean_absolute_percentage_error'])
monitor = EarlyStopping(monitor='mean_absolute_percentage_error', min_delta=.00001, 
                        patience=5, verbose=1, mode='auto')
model.fit(train_x,train_y, verbose = 0, callbacks=[monitor], epochs=30)

model.evaluate(test_x, test_y, sample_weight=None)
# Out:
# 349/349 [==============================] - 0s 475us/step
# [0.005155916683333138, 693.918082983241]

# %%
# Predict and measure RMSE
pred = model.predict(test_x)
score = np.sqrt(metrics.mean_squared_error(pred,test_y))
print("Score (RMSE): {}".format(score))
# Out:
# Score (RMSE): 0.07180471172698584

# %%
plt.plot(range(0,349),test_y,label='Actual')
plt.plot(range(0,349), pred,label='Prediction')
plt.ylabel('output')
plt.legend()
plt.show()

# %%
def dropval(series, position=0, days=1, percent=0):
    result = np.array([])
    progress = (percent/100)/days
    print("Step of progress {}".format(progress))
    if position!=0:
        result = np.append(result, series[:position])
    if(progress==0):
        print("No drop value mentioned")
    else:
        for i in range(days):
            loc = (len(series) - (position+i+1))
            print("loc is {}".format(loc))
            print("Series original val {}".format(series[loc]))
            result = np.append(result, (series[loc] - abs(series[loc] * (i+1) * progress)))
        result = np.append(result, series[(position+days):])
    return result

# %%
org_price = test_x['JPY_USD_Price'].copy()
new_price = org_price.copy()

print(new_price[10:15])
new_price = dropval(new_price,position=10,days=5,percent=20)
print(new_price[10:15])
# Out:
# 338   -0.215141
# 337   -0.195910
# 336   -0.215141
# 335   -0.195910
# 334   -0.195910
# Name: JPY_USD_Price, dtype: float64
# Step of progress 0.04
# loc is 338
# Series original val -0.21514092272406518
# loc is 337
# Series original val -0.19591015349329607
# loc is 336
# Series original val -0.21514092272406518
# loc is 335
# Series original val -0.19591015349329607
# loc is 334
# Series original val -0.19591015349329607
# [-0.22374656 -0.21158297 -0.24095783 -0.22725578 -0.23509218]

# %%
#org_price = test_x['JPY_USD_Price']
test_x['JPY_USD_Price'] = new_price

pred2 = model.predict(test_x)
score = np.sqrt(metrics.mean_squared_error(pred2,test_y))
test_x['JPY_USD_Price'] = org_price

print("Score (RMSE): {}".format(score))
# Out:
# Score (RMSE): 0.07179127973975488

# %%
plt.plot(range(0,10),test_y[10:20],label='Actual')
plt.plot(range(0,10),pred[10:20],label='Prediction')
plt.plot(range(0,10), pred2[10:20],label='Prediction after Shock')
ax = plt.subplot(111)
plt.ylabel('output')
ax.legend(loc='lower left')
plt.show()

# %%
test_x['JPY_USD_Price'] = org_price

# %%
np.sqrt(metrics.mean_squared_error(pred2,pred))
# Out:
# 0.00024439936

# %%
train_x = train_data['CAD_USD_Price']
test_x = test_data['CAD_USD_Price']
train_y = train_dep['CAD_USD_Price']
test_y = test_dep['CAD_USD_Price']

# %%
n_stocks = train_x.shape[1]

# %%
model1 = Sequential()
model1.add(Dense(100, input_dim=n_stocks, activation='linear'))
model1.add(Dense(50, activation='linear'))
model1.add(Dense(25, activation='linear'))
model1.add(Dense(10, activation='linear'))
model1.add(Dense(1, activation='linear'))
model1.compile(loss='mse', optimizer='adam',
             metrics=['mean_absolute_percentage_error'])
monitor = EarlyStopping(monitor='mean_absolute_percentage_error', min_delta=.00001, 
                        patience=5, verbose=1, mode='auto')
model1.fit(train_x,train_y, verbose = 0, epochs=30)

model1.evaluate(test_x, test_y, sample_weight=None)
# Out:
# 349/349 [==============================] - 0s 482us/step
# [0.0030295897974368493, 18.615865436870937]

# %%
# Predict and measure RMSE
pred = model1.predict(test_x)
score = np.sqrt(metrics.mean_squared_error(pred,test_y))
print("Score (RMSE): {}".format(score))
# Out:
# Score (RMSE): 0.055041708946002216

# %%
plt.plot(range(0,349),test_y,label='Actual')
plt.plot(range(0,349), pred,label='Prediction')
plt.ylabel('output')
plt.legend()
plt.show()

# %%
#new_price = test_x['JPY_USD_Price'].apply(dropval)

# %%
#org_price = test_x['JPY_USD_Price']
test_x['JPY_USD_Price'] = new_price

pred2 = model1.predict(test_x)
score = np.sqrt(metrics.mean_squared_error(pred2,test_y))
test_x['JPY_USD_Price'] = org_price

print("Score (RMSE): {}".format(score))
# Out:
# Score (RMSE): 0.05500991333941457

# %%
plt.plot(range(10,20),test_y[10:20],label='Actual')
plt.plot(range(10,20),pred[10:20],label='Prediction')
plt.plot(range(10,20), pred2[10:20],label='Prediction after Shock')
plt.ylabel('output')
plt.legend()
plt.show()

# %%
np.sqrt(metrics.mean_squared_error(pred2,pred))
# Out:
# 0.00042828292

# %% [markdown]
# - Shock to small data in the series and find the prediction.
